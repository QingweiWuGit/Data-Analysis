# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %% [markdown]
# # Yahoo Finance

# %%
import time

def download_with_retry(ticker, start, end, attempts=5, delay=30):
    for attempt in range(1, attempts + 1):
        try:
            return yf.download(ticker, start=start, end=end, progress=False)
        except Exception as e:
            msg = str(e)
            if 'YFRateLimitError' in msg or 'rate limited' in msg.lower():
                wait = delay * attempt
                print(f'Rate limited by Yahoo Finance. Retry {attempt}/{attempts} after {wait} seconds...')
                time.sleep(wait)
                continue
            raise
    raise RuntimeError(f'Failed to download {ticker} after {attempts} retries')

df = download_with_retry('AAPL', start='2020-01-01', end='2025-12-31')
df.head()
# Out:
# 1 Failed download:
# ['AAPL']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [(Adj Close, AAPL), (Close, AAPL), (High, AAPL), (Low, AAPL), (Open, AAPL), (Volume, AAPL)]
# Index: []

# %%
aapl_data = yf.Ticker('AAPL')
aapl_data.history(period='1mo')
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[7], line 2
#       1 aapl_data = yf.Ticker('AAPL')
# ----> 2 aapl_data.history(period='1mo')
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/utils.py:123, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     120 logger.debug(f'Entering {func.__name__}()')
#     122 with IndentationContext():
# --> 123     result = func(*args, **kwargs)
#     125 logger.debug(f'Exiting {func.__name__}()')
#     126 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/base.py:129, in TickerBase.history(self, *args, **kwargs)
#     127 @utils.log_indent_decorator
#     128 def history(self, *args, **kwargs) -> pd.DataFrame:
# --> 129     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/base.py:135, in TickerBase._lazy_load_price_history(self)
#     133 def _lazy_load_price_history(self):
#     134     if self._price_history is None:
# --> 135         self._price_history = PriceHistory(self._data, self.ticker, self._get_ticker_tz(timeout=10))
#     136     return self._price_history
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/base.py:150, in TickerBase._get_ticker_tz(self, timeout)
#     147     tz = None
#     149 if tz is None:
# --> 150     tz = self._fetch_ticker_tz(timeout)
#     151     if tz is None:
#     152         # _fetch_ticker_tz works in 99.999% of cases.
#     153         # For rare fail get from info.
#     154         global _tz_info_fetch_ctr
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/utils.py:123, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     120 logger.debug(f'Entering {func.__name__}()')
#     122 with IndentationContext():
# --> 123     result = func(*args, **kwargs)
#     125 logger.debug(f'Exiting {func.__name__}()')
#     126 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/base.py:182, in TickerBase._fetch_ticker_tz(self, timeout)
#     179 url = f"{_BASE_URL_}/v8/finance/chart/{self.ticker}"
#     181 try:
# --> 182     data = self._data.cache_get(url=url, params=params, timeout=timeout)
#     183     data = data.json()
#     184 except YFRateLimitError:
#     185     # Must propagate this
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/data.py:46, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      44 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      45 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 46 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/data.py:467, in YfData.cache_get(self, url, params, timeout)
#     464 @lru_cache_freezeargs
#     465 @lru_cache(maxsize=cache_maxsize)
#     466 def cache_get(self, url, params=None, timeout=30):
# --> 467     return self.get(url, params, timeout)
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/utils.py:123, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     120 logger.debug(f'Entering {func.__name__}()')
#     122 with IndentationContext():
# --> 123     result = func(*args, **kwargs)
#     125 logger.debug(f'Exiting {func.__name__}()')
#     126 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/data.py:384, in YfData.get(self, url, params, timeout)
#     382 @utils.log_indent_decorator
#     383 def get(self, url, params=None, timeout=30):
# --> 384     response = self._make_request(url, request_method = self._session.get, params=params, timeout=timeout)
#     386     # Accept cookie-consent if redirected to consent page
#     387     if not self._is_this_consent_url(response.url):
#     388         # "Consent Page not detected"
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/utils.py:123, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     120 logger.debug(f'Entering {func.__name__}()')
#     122 with IndentationContext():
# --> 123     result = func(*args, **kwargs)
#     125 logger.debug(f'Exiting {func.__name__}()')
#     126 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/yfinance/data.py:460, in YfData._make_request(self, url, request_method, body, params, timeout, data)
#     458     # Raise exception if rate limited
#     459     if response.status_code == 429:
# --> 460         raise YFRateLimitError()
#     462 return response
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.

# %% [markdown]
# # Nasdaq Data
